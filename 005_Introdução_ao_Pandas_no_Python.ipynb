# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxVieiraSantiago/Python/blob/master/005_Introdu%C3%A7%C3%A3o_ao_Pandas_no_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pandas - A melhor biblioteca do Python para Dados**

# %%
# Importando o Pandas
import pandas as pd

# %% [markdown]
# **Criando um DataFrame a partir de um Dicionário**

# %%
# DataFrame = pd.DataFrame()

vendas = { 'data': [ '15/05/2023', '16/05/2023' ],
           'valor': [ 500, 300 ],
           'produto': [ 'feijão', 'arroz' ],
           'qtde': [ 50, 70 ]
         }

vendas_df = pd.DataFrame( vendas )

# %% [markdown]
# **Visualização dos Dados**

# %%
print( vendas_df )
# Out:
#          data  valor produto  qtde
# 0  15/05/2023    500  feijão    50
# 1  16/05/2023    300   arroz    70

# %%
display( vendas_df )
# Out:
#          data  valor produto  qtde
# 0  15/05/2023    500  feijão    50
# 1  16/05/2023    300   arroz    70

# %% [markdown]
# **Importando Arquivos e Bases de Dados**

# %%
from google.colab import drive
drive.mount( '/content/drive'  )
# Out:
# Mounted at /content/drive

# %%
vendas_df = pd.read_excel( 'Vendas.xlsx' )

# %%
display( vendas_df )
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# ...

# %%
vendas_df.head()
# Out:
#    Código Venda       Data             ID Loja         Produto  Quantidade  \
# 0             1 2019-01-01  Iguatemi Esplanada  Sapato Estampa           1
# 1             1 2019-01-01  Iguatemi Esplanada        Camiseta           2
# 2             1 2019-01-01  Iguatemi Esplanada   Sapato Xadrez           1
# 3             2 2019-01-02      Norte Shopping         Relógio           3
# 4             2 2019-01-02      Norte Shopping    Chinelo Liso           1
#
#    Valor Unitário  Valor Final
# 0             358          358
# 1             180          360
# 2             368          368
# 3             200          600
# 4              71           71

# %%
vendas_df.shape
# Out:
# (93910, 7)

# %%
vendas_df.describe()
# Out:
#        Código Venda    Quantidade  Valor Unitário   Valor Final
# count  93910.000000  93910.000000    93910.000000  93910.000000
# mean   32464.762155      2.166553      191.725886    414.862656
# std    18809.007093      1.258732      145.215519    434.846228
# min        1.000000      1.000000       30.000000     30.000000
# 25%    16204.000000      1.000000      100.000000    156.000000
# 50%    32367.000000      2.000000      155.000000    274.000000
# 75%    48793.750000      3.000000      248.000000    524.000000
# max    65014.000000      5.000000      750.000000   3750.000000

# %% [markdown]
# **Pegar uma Única Coluna ( neste caso, uma única coluna é um  pd.Series )**

# %%
produtos = vendas_df['Produto']
display( produtos )
# Out:
# 0           Sapato Estampa
# 1                 Camiseta
# 2            Sapato Xadrez
# 3                  Relógio
# 4             Chinelo Liso
#                ...
# 93905       Mochila Xadrez
# 93906    Pulseira Listrado
# 93907       Cueca Listrado
# 93908       Pulseira Linho
# 93909        Casaco Xadrez
# Name: Produto, Length: 93910, dtype: object

# %% [markdown]
# **Pegar mais de Uma Coluna ( aí é um DataFrame )**

# %%
colunas = vendas_df[ [ 'Produto', 'ID Loja' ] ]
display( colunas )
# Out:
#                  Produto              ID Loja
# 0         Sapato Estampa   Iguatemi Esplanada
# 1               Camiseta   Iguatemi Esplanada
# 2          Sapato Xadrez   Iguatemi Esplanada
# 3                Relógio       Norte Shopping
# 4           Chinelo Liso       Norte Shopping
# ...                  ...                  ...
# 93905     Mochila Xadrez  Shopping Vila Velha
# 93906  Pulseira Listrado    Ribeirão Shopping
# 93907     Cueca Listrado    Ribeirão Shopping
# 93908     Pulseira Linho     Shopping Morumbi
# 93909      Casaco Xadrez     Shopping Morumbi
#
# [93910 rows x 2 columns]

# %% [markdown]
# ### **.loc  -> um método muito importante**
#
# - Pegar 1 linha.
# - Pegar linhas de acordo com alguma condição.
# - Pegar linhas e colunas específicas.
# - Pegar 1 valor específico.

# %%
# Pegar uma linha
display( vendas_df.loc[ 1 ] )
# Out:
# Código Venda                        1
# Data              2019-01-01 00:00:00
# ID Loja            Iguatemi Esplanada
# Produto                      Camiseta
# Quantidade                          2
# Valor Unitário                    180
# Valor Final                       360
# Name: 1, dtype: object

# %%
display( vendas_df.loc[ 1: 5 ] )
# Out:
#    Código Venda       Data                     ID Loja        Produto  \
# 1             1 2019-01-01          Iguatemi Esplanada       Camiseta
# 2             1 2019-01-01          Iguatemi Esplanada  Sapato Xadrez
# 3             2 2019-01-02              Norte Shopping        Relógio
# 4             2 2019-01-02              Norte Shopping   Chinelo Liso
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza    Cinto Linho
#
#    Quantidade  Valor Unitário  Valor Final
# 1           2             180          360
# 2           1             368          368
# 3           3             200          600
# 4           1              71           71
# 5           1             248          248

# %%
# Pegar linhas que correspondem a uma condição
display( vendas_df.loc[ vendas_df['ID Loja'] == 'Norte Shopping' ] )
# Out:
#        Código Venda       Data         ID Loja                 Produto  \
# 3                 2 2019-01-02  Norte Shopping                 Relógio
# 4                 2 2019-01-02  Norte Shopping            Chinelo Liso
# 8                 7 2019-01-02  Norte Shopping  Camisa Gola V Listrado
# 9                 7 2019-01-02  Norte Shopping             Camisa Liso
# 100              73 2019-01-02  Norte Shopping            Cueca Xadrez
# ...             ...        ...             ...                     ...
# 93716         64888 2019-11-30  Norte Shopping             Polo Xadrez
# 93754         64914 2019-11-30  Norte Shopping              Calça Liso
# 93755         64914 2019-11-30  Norte Shopping          Casaco Estampa
# 93756         64914 2019-11-30  Norte Shopping                   Gorro
# 93852         64980 2019-11-30  Norte Shopping           Bermuda Linho
#
#        Quantidade  Valor Unitário  Valor Final
# 3               3             200          600
# ...

# %%
# Podemos armazenar
vendas_norteshopping_df = vendas_df.loc[ vendas_df['ID Loja'] == 'Norte Shopping' ]

display( vendas_norteshopping_df )
# Out:
#        Código Venda       Data         ID Loja                 Produto  \
# 3                 2 2019-01-02  Norte Shopping                 Relógio
# 4                 2 2019-01-02  Norte Shopping            Chinelo Liso
# 8                 7 2019-01-02  Norte Shopping  Camisa Gola V Listrado
# 9                 7 2019-01-02  Norte Shopping             Camisa Liso
# 100              73 2019-01-02  Norte Shopping            Cueca Xadrez
# ...             ...        ...             ...                     ...
# 93716         64888 2019-11-30  Norte Shopping             Polo Xadrez
# 93754         64914 2019-11-30  Norte Shopping              Calça Liso
# 93755         64914 2019-11-30  Norte Shopping          Casaco Estampa
# 93756         64914 2019-11-30  Norte Shopping                   Gorro
# 93852         64980 2019-11-30  Norte Shopping           Bermuda Linho
#
#        Quantidade  Valor Unitário  Valor Final
# 3               3             200          600
# ...

# %%
# Pegar várias Linhas e Colunas 

# vendas_norte_shopping_df = vendas_df.loc[ linhas, colunas ]

vendas_norte_shopping_df = vendas_df.loc[ vendas_df['ID Loja'] == 'Norte Shopping' , [ 'ID Loja', 'Produto', 'Quantidade' ] ]

display( vendas_norte_shopping_df )
# Out:
#               ID Loja                 Produto  Quantidade
# 3      Norte Shopping                 Relógio           3
# 4      Norte Shopping            Chinelo Liso           1
# 8      Norte Shopping  Camisa Gola V Listrado           1
# 9      Norte Shopping             Camisa Liso           1
# 100    Norte Shopping            Cueca Xadrez           5
# ...               ...                     ...         ...
# 93716  Norte Shopping             Polo Xadrez           1
# 93754  Norte Shopping              Calça Liso           1
# 93755  Norte Shopping          Casaco Estampa           2
# 93756  Norte Shopping                   Gorro           2
# 93852  Norte Shopping           Bermuda Linho           1
#
# [3924 rows x 3 columns]

# %%
# Pegar um Item Específico
print( vendas_df.loc[ 1, 'Produto' ] )
# Out:
# Camiseta

# %% [markdown]
# **Adicionar Uma Coluna**

# %%
# A partir de uma coluna que já existe
vendas_df['Comissao'] = vendas_df['Valor Final'] * 0.05
display( vendas_df )

# Ciar uma Coluna com valor Padrão
# vendas_df.loc[ linhas, colunas ]
vendas_df.loc[ : , 'Imposto' ] = 0
display( vendas_df )
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final  Comissao
# 0               1             358          358     17.90
# ...

# %% [markdown]
# **Adicionar Uma Linha**
#
# - Linhas de um complemento da base de dados

# %%
vendas_dez_df = pd.read_excel( 'Vendas - Dez.xlsx')

vendas_df = vendas_df.append( vendas_dez_df )
vendas_df.tail()
# Out:
# <ipython-input-17-ac752010a62b>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vendas_df = vendas_df.append( vendas_dez_df )
#       Código Venda       Data                     ID Loja           Produto  \
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final  Comissao  Imposto
# 7084           2             102          204       NaN      NaN
# 7085           4             270         1080       NaN      NaN
# 7086           1              87           87       NaN      NaN
# ...

# %%
# Lembrando que as Colunas 'Comissao' e 'Imposto' foram adicionadas em vendas_df e NÃO em vendas_dez_df
vendas_df.loc[ :, 'Comissao' ] = vendas_df['Valor Final'] * 0.05
vendas_df.loc[ :, 'Imposto'  ] = 0

display( vendas_df )
# Out:
# <ipython-input-18-078806cb9af1>:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   vendas_df.loc[ :, 'Imposto'  ] = 0
#       Código Venda       Data                     ID Loja           Produto  \
# 0                1 2019-01-01          Iguatemi Esplanada    Sapato Estampa
# 1                1 2019-01-01          Iguatemi Esplanada          Camiseta
# 2                1 2019-01-01          Iguatemi Esplanada     Sapato Xadrez
# 3                2 2019-01-02              Norte Shopping           Relógio
# 4                2 2019-01-02              Norte Shopping      Chinelo Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# ...

# %% [markdown]
# **Excluir Linhas e Colunas**

# %%
# Excluir uma Coluna
vendas_df = vendas_df.drop( 'Imposto', axis=1 )

# Excluir Linha
# vendas_df = vendas_df.drop( 0, axis=0 )

display( vendas_df )
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0                1 2019-01-01          Iguatemi Esplanada    Sapato Estampa
# 1                1 2019-01-01          Iguatemi Esplanada          Camiseta
# 2                1 2019-01-01          Iguatemi Esplanada     Sapato Xadrez
# 3                2 2019-01-02              Norte Shopping           Relógio
# 4                2 2019-01-02              Norte Shopping      Chinelo Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final  Comissao
# ...

# %% [markdown]
# **Valores Vazios**
#
# - Deletar Linhas/Colunas Vazias.
# - Deletar Linhas que possuem valores vazios.
# - Preencher valores vazios ( média e último valor ).

# %%
vendas_df.head()
# Out:
#    Código Venda       Data             ID Loja         Produto  Quantidade  \
# 0             1 2019-01-01  Iguatemi Esplanada  Sapato Estampa           1
# 1             1 2019-01-01  Iguatemi Esplanada        Camiseta           2
# 2             1 2019-01-01  Iguatemi Esplanada   Sapato Xadrez           1
# 3             2 2019-01-02      Norte Shopping         Relógio           3
# 4             2 2019-01-02      Norte Shopping    Chinelo Liso           1
#
#    Valor Unitário  Valor Final  Comissao
# 0             358          358     17.90
# 1             180          360     18.00
# 2             368          368     18.40
# 3             200          600     30.00
# 4              71           71      3.55

# %%
# Deletar linhas e colunas completamente vazias
vendas_df = vendas_df.dropna( how = 'all' )

# %%
# Coluna
vendas_df = vendas_df.dropna( how='all', axis = 1 )

# %%
# Deletar linhas que possuem pelo menos um valor vazio
vendas_df = vendas_df.dropna()

# %%
# Preencher valores vazios

# Preencher os valores VAZIOS com a média da coluna
vendas_df['Comissao'] = vendas_df['Comissao'].fillna( vendas_df['Comissao'].mean() )

# %%
# Preencher os valores VAZIOS com o último valor
vendas_df = vendas_df.ffill()

# %%
vendas_df.head()
# Out:
#    Código Venda       Data             ID Loja         Produto  Quantidade  \
# 0             1 2019-01-01  Iguatemi Esplanada  Sapato Estampa           1
# 1             1 2019-01-01  Iguatemi Esplanada        Camiseta           2
# 2             1 2019-01-01  Iguatemi Esplanada   Sapato Xadrez           1
# 3             2 2019-01-02      Norte Shopping         Relógio           3
# 4             2 2019-01-02      Norte Shopping    Chinelo Liso           1
#
#    Valor Unitário  Valor Final  Comissao
# 0             358          358     17.90
# 1             180          360     18.00
# 2             368          368     18.40
# 3             200          600     30.00
# 4              71           71      3.55

# %% [markdown]
# ### **Calcular Indicadores**
#
# - Groupby
# - Values Counts

# %%
# value_counts
transacoes_por_loja = vendas_df['ID Loja'].value_counts()


# group by
faturamento_produto = vendas_df[ ['Produto', 'Valor Final'] ].groupby('Produto').sum()
display( faturamento_produto )
# Out:
#                   Valor Final
# Produto
# Bermuda                272250
# Bermuda Estampa        291694
# Bermuda Linho          394680
# Bermuda Liso           275692
# Bermuda Listrado       293237
# ...                       ...
# Tênis Estampa          457728
# Tênis Linho            538608
# Tênis Liso             474544
# Tênis Listrado         481032
# Tênis Xadrez           459725
#
# [120 rows x 1 columns]

# %% [markdown]
# **Mesclar 2 DataFrames**

# %%
gerentes_df = pd.read_excel( 'Gerentes.xlsx')
gerentes_df.head()
# Out:
#                       ID Loja   Gerente
# 0          Iguatemi Esplanada  Salvador
# 1              Norte Shopping     Joana
# 2  Rio Mar Shopping Fortaleza     Maria
# 3              Shopping Barra   Letícia
# 4         Shopping Ibirapuera    Helena

# %%
# Como os dois arquivos possuem o campo ID Loja, o Python identifica automaticamente e faz o MERGE.
vendas_df = vendas_df.merge( gerentes_df )
vendas_df.head()
# Out:
#    Código Venda       Data             ID Loja                 Produto  \
# 0             1 2019-01-01  Iguatemi Esplanada          Sapato Estampa
# 1             1 2019-01-01  Iguatemi Esplanada                Camiseta
# 2             1 2019-01-01  Iguatemi Esplanada           Sapato Xadrez
# 3            21 2019-01-02  Iguatemi Esplanada  Camisa Gola V Listrado
# 4            34 2019-01-02  Iguatemi Esplanada         Sapato Listrado
#
#    Quantidade  Valor Unitário  Valor Final  Comissao   Gerente
# 0           1             358          358     17.90  Salvador
# 1           2             180          360     18.00  Salvador
# 2           1             368          368     18.40  Salvador
# 3           2             116          232     11.60  Salvador
# 4           1             363          363     18.15  Salvador
